# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
# imports

import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import time
import mediapipe as mp

# %%
# Load sequences and labels from disk
# sequences = np.load('../sequences.npy')
# labels = np.load('../labels.npy')

# Load sequences and labels from disk

sequences_augmented = np.load('../sequences_augmented.npy')
labels_augmented = np.load('../labels_augmented.npy')

################!!!!!!!!!!!!!!!!!!!!! they are now nparrays instead of lists, so no need to convert them to nparrays again in the code below

# %%
X = sequences_augmented
y= to_categorical(labels_augmented).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from tensorflow import keras
from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.callbacks import TensorBoard

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense
from keras.optimizers import Adam

# Define the model
model = Sequential()
model.add(GRU(64, return_sequences=True, input_shape=(30, 1662)))  # GRU layer
model.add(LSTM(128))  # LSTM layer
model.add(Dense(65, activation='relu'))
model.add(Dense(65, activation='softmax'))  # 64 classes

# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

from keras.callbacks import EarlyStopping

# Define the early stopping monitor
early_stopping_monitor = EarlyStopping(patience=3)

# Fit the model to the data
model.fit(X_train, y_train, epochs=150, validation_split=0.2, callbacks=[early_stopping_monitor])
# Out:
# C:\Users\Steve\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - accuracy: 0.0181 - loss: 4.1645 - val_accuracy: 0.0556 - val_loss: 3.8908
# Epoch 2/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.0736 - loss: 3.7050 - val_accuracy: 0.0991 - val_loss: 3.3525
# Epoch 3/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.1327 - loss: 3.1983 - val_accuracy: 0.1521 - val_loss: 3.1563
# Epoch 4/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.1923 - loss: 2.8336 - val_accuracy: 0.2538 - val_loss: 2.6020
# Epoch 5/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.2905 - loss: 2.4507 - val_accuracy: 0.3590 - val_loss: 2.2333
# Epoch 6/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.3766 - loss: 2.0894 - val_accuracy: 0.4291 - val_loss: 1.8445
# Epoch 7/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.4581 - loss: 1.7303 - val_accuracy: 0.5299 - val_loss: 1.5685
# Epoch 8/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.5266 - loss: 1.4674 - val_accuracy: 0.5350 - val_loss: 1.4426
# Epoch 9/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6130 - loss: 1.2055 - val_accuracy: 0.6359 - val_loss: 1.1563
# Epoch 10/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.6525 - loss: 1.0619 - val_accuracy: 0.6376 - val_loss: 1.1256
# Epoch 11/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.6901 - loss: 0.9282 - val_accuracy: 0.6872 - val_loss: 0.9654
# Epoch 12/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7288 - loss: 0.8048 - val_accuracy: 0.7316 - val_loss: 0.8108
# Epoch 13/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.7504 - loss: 0.7313 - val_accuracy: 0.7128 - val_loss: 0.8718
# Epoch 14/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.7927 - loss: 0.6145 - val_accuracy: 0.7479 - val_loss: 0.7677
# Epoch 15/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.7869 - loss: 0.6254 - val_accuracy: 0.7641 - val_loss: 0.7130
# Epoch 16/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8137 - loss: 0.5253 - val_accuracy: 0.8197 - val_loss: 0.5598
# Epoch 17/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8600 - loss: 0.4218 - val_accuracy: 0.7641 - val_loss: 0.7284
# Epoch 18/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.7816 - loss: 0.6278 - val_accuracy: 0.7145 - val_loss: 0.8979
# Epoch 19/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8345 - loss: 0.4963 - val_accuracy: 0.8137 - val_loss: 0.5458
# Epoch 20/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8602 - loss: 0.3874 - val_accuracy: 0.8385 - val_loss: 0.5187
# Epoch 21/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8752 - loss: 0.3456 - val_accuracy: 0.8462 - val_loss: 0.4851
# Epoch 22/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8863 - loss: 0.3225 - val_accuracy: 0.8342 - val_loss: 0.4560
# Epoch 23/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9012 - loss: 0.2734 - val_accuracy: 0.8470 - val_loss: 0.4473
# Epoch 24/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8981 - loss: 0.3087 - val_accuracy: 0.8581 - val_loss: 0.4388
# Epoch 25/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.9102 - loss: 0.2591 - val_accuracy: 0.7812 - val_loss: 0.6694
# Epoch 26/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.8822 - loss: 0.3336 - val_accuracy: 0.8838 - val_loss: 0.3808
# Epoch 27/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9070 - loss: 0.2748 - val_accuracy: 0.8248 - val_loss: 0.4913
# Epoch 28/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.8942 - loss: 0.2924 - val_accuracy: 0.8795 - val_loss: 0.3673
# Epoch 29/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.9289 - loss: 0.2065 - val_accuracy: 0.8957 - val_loss: 0.3367
# Epoch 30/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.9276 - loss: 0.2080 - val_accuracy: 0.8231 - val_loss: 0.5536
# Epoch 31/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9074 - loss: 0.2502 - val_accuracy: 0.8863 - val_loss: 0.3555
# Epoch 32/150
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.9388 - loss: 0.1731 - val_accuracy: 0.8598 - val_loss: 0.4236

# %%
model.save('../actions/actions_gru_lstm.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import accuracy_score, classification_report, multilabel_confusion_matrix


y_pred = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
ypred = np.argmax(y_pred, axis=1).tolist()

print(accuracy_score(ytrue, ypred))
multilabel_confusion_matrix(ytrue, ypred)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 0.8415384615384616
# array([[[635,   1],
#         [  3,  11]],
#
#        [[630,  10],
#         [  2,   8]],
#
#        [[632,   2],
#         [ 11,   5]],
#
#        [[637,   0],
#         [  1,  12]],
#
#        [[635,   2],
#         [  4,   9]],
#
#        [[638,   1],
#         [  4,   7]],
#
#        [[638,   5],
#         [  3,   4]],
#
#        [[639,   2],
#         [  0,   9]],
#
#        [[642,   2],
#         [  1,   5]],
#
#        [[642,   4],
#         [  1,   3]],
#
#        [[638,   1],
#         [  4,   7]],
#
#        [[640,   2],
#         [  3,   5]],
#
#        [[640,   2],
#         [  1,   7]],
#
#        [[635,   3],
#         [  1,  11]],
#
#        [[636,   3],
#         [  2,   9]],
#
#        [[637,   3],
#         [  0,  10]],
#
#        [[638,   1],
#         [  0,  11]],
#
#        [[637,   3],
#         [  2,   8]],
#
#        [[636,   3],
#         [  0,  11]],
#
#        [[643,   2],
#         [  1,   4]],
#
#        [[639,   4],
#         [  0,   7]],
#
#        [[639,   2],
#         [  0,   9]],
#
#        [[642,   1],
#         [  3,   4]],
#
#        [[639,   1],
#         [  1,   9]],
#
#        [[637,   4],
#         [  1,   8]],
#
#        [[639,   0],
#         [  1,  10]],
#
#        [[638,   1],
#         [  2,   9]],
#
#        [[642,   0],
#         [  1,   7]],
#
#        [[640,   0],
#         [  4,   6]],
#
#        [[632,   4],
#         [  4,  10]],
#
#        [[637,   1],
#         [  1,  11]],
#
#        [[634,   0],
#         [  0,  16]],
#
#        [[636,   0],
#         [  4,  10]],
#
#        [[636,   0],
#         [  0,  14]],
#
#        [[639,   1],
#         [  1,   9]],
#
#        [[647,   0],
#         [  0,   3]],
#
#        [[642,   1],
#         [  0,   7]],
#
#        [[641,   0],
#         [  1,   8]],
#
#        [[631,   5],
#         [  3,  11]],
#
#        [[640,   0],
#         [  0,  10]],
#
#        [[641,   1],
#         [  1,   7]],
#
#        [[642,   1],
#         [  4,   3]],
#
#        [[640,   2],
#         [  0,   8]],
#
#        [[637,   1],
#         [  1,  11]],
#
#        [[641,   0],
#         [  0,   9]],
#
#        [[641,   2],
#         [  1,   6]],
#
#        [[640,   0],
#         [  1,   9]],
#
#        [[642,   0],
#         [  1,   7]],
#
#        [[644,   1],
#         [  0,   5]],
#
#        [[637,   2],
#         [  3,   8]],
#
#        [[637,   0],
#         [  4,   9]],
#
#        [[642,   0],
#         [  1,   7]],
#
#        [[642,   0],
#         [  0,   8]],
#
#        [[635,   1],
#         [  4,  10]],
#
#        [[636,   0],
#         [  1,  13]],
#
#        [[644,   0],
#         [  0,   6]],
#
#        [[634,   4],
#         [  1,  11]],
#
#        [[637,   0],
#         [  1,  12]],
#
#        [[644,   1],
#         [  2,   3]],
#
#        [[640,   0],
#         [  0,  10]],
#
#        [[634,   2],
#         [  0,  14]],
#
#        [[634,   1],
#         [  4,  11]],
#
#        [[639,   3],
#         [  0,   8]],
#
#        [[636,   4],
#         [  2,   8]],
#
#        [[640,   0],
#         [  0,  10]]], dtype=int64)
